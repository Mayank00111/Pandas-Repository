# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('orders.txt')

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
df1 = pd.read_csv('dog_data_short.csv')

# %%
df1
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
#ADD column from list
gender = ["Male","Female","Male","Male","Female"]
df1["Gender"] = gender                      #this is great for small data set

# %%
df1
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female

# %%
#Add default values
df1["Alive/Dead"] = [True]*len(df1)                                    #inplace of True u can give anything

# %%
df1
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True

# %%
#Add NaN values
df1["Show Dog"] = [np.nan]*len(df1)
df1
# Out:
#                  Breed        Color  DogName  OwnerZip  Gender  Alive/Dead  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    Male        True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238  Female        True
# 2        BELG MALINOIS      BRINDLE     EICH     15238    Male        True
# 3                MIXED  BLACK/BROWN    ARROW     15104    Male        True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  Female        True
#
#    Show Dog
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
#Add column with .insert - Allows position
df1.insert(1, "Adopted", [True]*len(df1), True)

# %%
df1
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender  \
# 0             COCKAPOO     True        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD     True  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS     True      BRINDLE     EICH     15238    Male
# 3                MIXED     True  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female
#
#    Alive/Dead  Show Dog
# 0        True       NaN
# 1        True       NaN
# 2        True       NaN
# 3        True       NaN
# 4        True       NaN

# %%
#Add column with .assign --- created new df
df2 = df1.assign(Horse= [False]*len(df1))
df2
# Out:
#                  Breed  Adopted        Color  DogName  OwnerZip  Gender  \
# 0             COCKAPOO     True        BROWN  CHARLEY     15236    Male
# 1         GER SHEPHERD     True  BLACK/BROWN   TACODA     15238  Female
# 2        BELG MALINOIS     True      BRINDLE     EICH     15238    Male
# 3                MIXED     True  BLACK/BROWN    ARROW     15104    Male
# 4  AM PIT BULL TERRIER     True  WHITE/BROWN   OAKLEY     15139  Female
#
#    Alive/Dead  Show Dog  Horse
# 0        True       NaN  False
# 1        True       NaN  False
# 2        True       NaN  False
# 3        True       NaN  False
# 4        True       NaN  False
